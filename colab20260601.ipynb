# %% [markdown]
# <a href="https://colab.research.google.com/github/Gop2/ALGESTDADOS20261/blob/main/colab20260601.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
lista_muito_daora = [1,2,3,4,5,67,8,9,9,9,10,67]
conjunto = set(lista_muito_daora)
nova_lista = sorted(list(conjunto))

print(lista_muito_daora)
print(conjunto)
print(nova_lista)

print(f"\nforam removidos {len(lista_muito_daora) - len(nova_lista)} elementos")
# Out:
# [1, 2, 3, 4, 5, 67, 8, 9, 9, 9, 10, 67]
# {1, 2, 3, 4, 5, 67, 8, 9, 10}
# [1, 2, 3, 4, 5, 8, 9, 10, 67]
#
# foram removidos 3 elementos

# %%
produtos = tuple(["banana", "cuzcuz", "goiaba", "ben 10", "atum"])
preços = tuple([67,69,200,123,677])
dicionario = dict(zip(produtos, preços))
massa = sorted(dicionario.items(), key=lambda item: item[1])

print(massa)
# Out:
# [('banana', 67), ('cuzcuz', 69), ('ben 10', 123), ('goiaba', 200), ('atum', 677)]

# %%
# Contabilizar a ocorrência de elementos em uma sequência é uma tarefa recorrente em análise de dados e processamento de texto.
# Escreva um programa que receba uma lista de palavras (definida no código) e construa um dict que mapeie cada palavra à sua frequência de aparição na lista.
# Após construir o dicionário, converta-o em uma lista de tuplas (palavra, frequência), ordene-a pela frequência em ordem decrescente e exiba os cinco elementos mais frequentes.
# Por fim, extraia apenas as palavras (chaves) como um conjunto (set) e exiba o vocabulário único identificado.

produtos_ruins = ["scooby loo", "mestre dos disfarces", "RE6", "zico"]
dic_produtos_ruins = {}

for produto in produtos_ruins:
    dic_produtos_ruins[produto]  = produtos_ruins.count(produto)

print(dic_produtos_ruins)
tuplas = tuple(sorted(dic_produtos_ruins.items(), key=lambda item: item[1], reverse=True))

for i in range(min(5, len(tuplas))):
    print(tuplas[i])

final = dict(tuplas)

print(set(final.keys()))
# Out:
# {'scooby loo': 1, 'mestre dos disfarces': 1, 'RE6': 1, 'zico': 1}
# ('scooby loo', 1)
# ('mestre dos disfarces', 1)
# ('RE6', 1)
# ('zico', 1)
# {'mestre dos disfarces', 'scooby loo', 'RE6', 'zico'}

# %%
# Tuplas são frequentemente utilizadas para representar registros estruturados e imutáveis.
# Defina uma lista de tuplas no formato (nome, idade, cidade) com ao menos 6 registros de pessoas.
# A partir dessa estrutura, escreva um programa que: (a) converta a lista em um dicionário cujas chaves sejam os nomes e os valores sejam tuplas (idade, cidade);
# (b) filtre e exiba apenas as pessoas com idade superior a 25 anos; (c) extraia todas as cidades como um set para obter as localidades únicas presentes nos dados.
# Exiba os resultados de cada etapa separadamente


pessoas = [
    ("rodrigo", 19, "nova venécia")
    ("gustavo", 67, "algum lugar na italia")
    ("kerokero",22, "la em casa tinha um pintinho, la em casa tinha um pintinho e o pintinho piu e o pintinho piu, e o pintinho piu e o pintinho piu")
    ("messi", 202, "em algum lugar na argentina")
]
